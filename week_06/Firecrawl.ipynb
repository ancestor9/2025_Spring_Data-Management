# %% [markdown]
# <a href="https://colab.research.google.com/github/ancestor9/2025_Spring_Data-Management/blob/main/week_06/Firecrawl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **[🔥Firecrawl](https://www.firecrawl.dev/)**

# %%
from google.colab import userdata
userdata.get('firecrawl')
# Out:
# 'fc-6146842f1ad14984976732165a6c3c4d'

# %%
from google.colab import userdata
firecrawl_api_key = userdata.get('firecrawl')

# %%
# Install with pip install firecrawl-py
! pip install firecrawl-py

# %%
# https://www.firecrawl.dev/playground

from firecrawl import FirecrawlApp

url = 'https://quotes.toscrape.com/'

app = FirecrawlApp(api_key=firecrawl_api_key)

response = app.scrape_url(url= url, params={
	'formats': [ 'markdown', 'links' ],
	'onlyMainContent': False
})

# %%
response
# Out:
# {'markdown': "# [Quotes to Scrape](https://quotes.toscrape.com/)\n\n[Login](https://quotes.toscrape.com/login)\n\n“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”by Albert Einstein [(about)](https://quotes.toscrape.com/author/Albert-Einstein)\n\nTags:\n\n\n[change](https://quotes.toscrape.com/tag/change/page/1/) [deep-thoughts](https://quotes.toscrape.com/tag/deep-thoughts/page/1/) [thinking](https://quotes.toscrape.com/tag/thinking/page/1/) [world](https://quotes.toscrape.com/tag/world/page/1/)\n\n“It is our choices, Harry, that show what we truly are, far more than our abilities.”by J.K. Rowling [(about)](https://quotes.toscrape.com/author/J-K-Rowling)\n\nTags:\n\n\n[abilities](https://quotes.toscrape.com/tag/abilities/page/1/) [choices](https://quotes.toscrape.com/tag/choices/page/1/)\n\n“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle
# ...

# %%
url = 'https://comic.naver.com/webtoon'

response = app.scrape_url(url=url, params={
	'formats': [ 'markdown', 'links' ],
	'onlyMainContent': False
})

# %%
response['markdown']
# Out:
# "[메인메뉴로 바로가기](https://comic.naver.com/webtoon#menu) [본문으로 바로가기](https://comic.naver.com/webtoon#container)\n\n# [NAVER](https://naver.com/) [웹툰](https://comic.naver.com/index) \\| [웹소설](https://novel.naver.com/) \\| [시리즈](https://series.naver.com/)\n\n검색\n\n**사용자 링크**\n\n- [로그인](https://nid.naver.com/nidlogin.login?url=https%3A%2F%2Fcomic.naver.com%2Fwebtoon)\n- [![내 프로필 이미지](<Base64-Image-Removed>)_내정보 보기_](javascript:;) [(임직원혜택)](https://comic.naver.com/webtoon#)\n\n\n\n\n\n![프로필 이미지](<Base64-Image-Removed>)[프로필 사진 변경](https://nid.naver.com/user2/api/naverProfile?m=checkIdType)\n\n\n\n\n\n[\\_](https://nid.naver.com/user2/api/naverProfile?m=checkIdType) 님 [로그아웃](https://nid.naver.com/nidlogin.logout?returl=https%3A%2F%2Fcomic.naver.com%2Fwebtoon)\n\n[@naver.com](https://mail.naver.com/)\n\n- [네이버ID](https://nid.naver.com/user2/help/myInfo?menu=home)\n- [보안설정](https://nid.naver.com/user2/help/myInfo?m=viewSecurity&menu=security)\n- [내인증서](https://nid.naver.com/user2/eSign/v1/home/la
# ...

# %%
response
# Out:
# {'markdown': "[메인메뉴로 바로가기](https://comic.naver.com/webtoon#menu) [본문으로 바로가기](https://comic.naver.com/webtoon#container)\n\n# [NAVER](https://naver.com/) [웹툰](https://comic.naver.com/index) \\| [웹소설](https://novel.naver.com/) \\| [시리즈](https://series.naver.com/)\n\n검색\n\n**사용자 링크**\n\n- [로그인](https://nid.naver.com/nidlogin.login?url=https%3A%2F%2Fcomic.naver.com%2Fwebtoon)\n- [![내 프로필 이미지](<Base64-Image-Removed>)_내정보 보기_](javascript:;) [(임직원혜택)](https://comic.naver.com/webtoon#)\n\n\n\n\n\n![프로필 이미지](<Base64-Image-Removed>)[프로필 사진 변경](https://nid.naver.com/user2/api/naverProfile?m=checkIdType)\n\n\n\n\n\n[\\_](https://nid.naver.com/user2/api/naverProfile?m=checkIdType) 님 [로그아웃](https://nid.naver.com/nidlogin.logout?returl=https%3A%2F%2Fcomic.naver.com%2Fwebtoon)\n\n[@naver.com](https://mail.naver.com/)\n\n- [네이버ID](https://nid.naver.com/user2/help/myInfo?menu=home)\n- [보안설정](https://nid.naver.com/user2/help/myInfo?m=viewSecurity&menu=security)\n- [내인증서](https://nid.naver.com/user2/eSi
# ...

# %%
import requests

cookies = {
    'NNB': 'ATDCZU4KXWMGO',
    '_fwb': '181EyXL2zPnHhRH8x1NXS9G.1738154372891',
    'landHomeFlashUseYn': 'Y',
    '_fwb': '181EyXL2zPnHhRH8x1NXS9G.1738154372891',
    'SHOW_FIN_BADGE': 'Y',
    'ASID': '70a9dd5100000194b59e386400000057',
    'NID_AUT': '9kYITJGQU0uJazzz33xPpVmVODcnCmMxh5kzkzoeDNhVNS7Nf7ejIyu6W1LwcesK',
    'NID_JKL': 'QL1V3ShM6oQBvdFMXBRS5pO5tFPoE3De/Sl9b3n7go4=',
    'NFS': '2',
    'BNB_FINANCE_HOME_TOOLTIP_MYASSET': 'true',
    'NAC': 'T9blBkQTMDZn',
    'nhn.realestate.article.rlet_type_cd': 'A01',
    'nhn.realestate.article.trade_type_cd': '""',
    'nhn.realestate.article.ipaddress_city': '1100000000',
    'NACT': '1',
    'realestate.beta.lastclick.cortar': '1174000000',
    'NID_SES': '...',
    'SRT30': '1744158416',
    'SRT5': '1744158416',
    'REALESTATE': 'Wed%20Apr%2009%202025%2009%3A27%3A00%20GMT%2B0900%20(Korean%20Standard%20Time)',
    'BUC': 'HGLVb9LDYdoQfVCieQTaYoOqq1REP9L3k9Pit5DTsXg=',
}

headers = {
    'accept': '*/*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IlJFQUxFU1RBVEUiLCJpYXQiOjE3NDQxNTg0MjAsImV4cCI6MTc0NDE2OTIyMH0.rtUyqoZH1wT0e6UKRw-xm0Z0kGIbVP5vbcb0iBzKu1k',
    'cache-control': 'no-cache',
    'pragma': 'no-cache',
    'priority': 'u=1, i',
    'referer': 'https://new.land.naver.com/complexes/155817?ms=37.5241115,127.1358731,16&a=APT:PRE:ABYG:JGC&e=RETAIL',
    'sec-ch-ua': '"Google Chrome";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36',
    # 'cookie': 'NNB=ATDCZU4KXWMGO; _fwb=181EyXL2zPnHhRH8x1NXS9G.1738154372891; landHomeFlashUseYn=Y; _fwb=181EyXL2zPnHhRH8x1NXS9G.1738154372891; SHOW_FIN_BADGE=Y; ASID=70a9dd5100000194b59e386400000057; NID_AUT=9kYITJGQU0uJazzz33xPpVmVODcnCmMxh5kzkzoeDNhVNS7Nf7ejIyu6W1LwcesK; NID_JKL=QL1V3ShM6oQBvdFMXBRS5pO5tFPoE3De/Sl9b3n7go4=; NFS=2; BNB_FINANCE_HOME_TOOLTIP_MYASSET=true; NAC=T9blBkQTMDZn; nhn.realestate.article.rlet_type_cd=A01; nhn.realestate.article.trade_type_cd=""; nhn.realestate.article.ipaddress_city=1100000000; NACT=1; realestate.beta.lastclick.cortar=1174000000; NID_SES=...; SRT30=1744158416; SRT5=1744158416; REALESTATE=Wed%20Apr%2009%202025%2009%3A27%3A00%20GMT%2B0900%20(Korean%20Standard%20Time); BUC=HGLVb9LDYdoQfVCieQTaYoOqq1REP9L3k9Pit5DTsXg=',
}

response = requests.get(
    'https://new.land.naver.com/api/articles/complex/155817?realEstateType=APT%3APRE%3AABYG%3AJGC&tradeType=&tag=%3A%3A%3A%3A%3A%3A%3A%3A&rentPriceMin=0&rentPriceMax=900000000&priceMin=0&priceMax=900000000&areaMin=0&areaMax=900000000&oldBuildYears&recentlyBuildYears&minHouseHoldCount&maxHouseHoldCount&showArticle=false&sameAddressGroup=false&minMaintenanceCost&maxMaintenanceCost&priceType=RETAIL&directions=&page=2&complexNo=155817&buildingNos=&areaNos=&type=list&order=rank',
    cookies=cookies,
    headers=headers,
)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'isMoreData': True,
#  'articleList': [{'articleNo': '2516259658',
#    'articleName': '올림픽파크포레온',
#    'articleStatus': 'R0',
#    'realEstateTypeCode': 'APT',
#    'realEstateTypeName': '아파트',
#    'articleRealEstateTypeCode': 'A01',
#    'articleRealEstateTypeName': '아파트',
#    'tradeTypeCode': 'B1',
#    'tradeTypeName': '전세',
#    'verificationTypeCode': 'S_VR',
#    'floorInfo': '28/30',
#    'priceChangeState': 'SAME',
#    'isPriceModification': True,
#    'dealOrWarrantPrc': '9억 5,000',
#    'areaName': '85A',
#    'area1': 85,
#    'area2': 59,
#    'direction': '남향',
#    'articleConfirmYmd': '20250328',
#    'representativeImgUrl': '/20250328_152/1743156482904XSByn_JPEG/384a39176b4cab7db905b71be935915b.JPG',
#    'representativeImgTypeCode': 'SITE',
#    'representativeImgThumb': 'f130_98',
#    'siteImageCount': 1,
#    'articleFeatureDesc': '진짜 가격 조합 냉장고3 에어컨4 세탁기 스타일러 풀풀옵션',
#    'tagList': ['2년이내', '대단지', '방세개', '화장실두개'],
#    'buildingName': '418동',
# ...

# %%
import requests
import pandas as pd
import time

def fetch_all_articles(complex_no):
    all_articles = []
    page = 1

    while True:
        url = (
            f"https://new.land.naver.com/api/articles/complex/{complex_no}"
            f"?realEstateType=APT%3APRE%3AABYG%3AJGC&tradeType=&tag=%3A%3A%3A%3A%3A%3A%3A%3A"
            f"&rentPriceMin=0&rentPriceMax=900000000&priceMin=0&priceMax=900000000"
            f"&areaMin=0&areaMax=900000000&priceType=RETAIL&page={page}"
            f"&complexNo={complex_no}&type=list&order=rank"
        )

        response = requests.get(url, headers=headers, cookies=cookies)
        if response.status_code != 200:
            print(f"페이지 {page}에서 오류 발생: {response.status_code}")
            break

        data = response.json()
        articles = data.get("articleList", [])
        if not articles:
            break

        for a in articles:
            all_articles.append({
                "매물번호": a.get("articleNo"),
                "이름": a.get("articleName"),
                "거래유형": a.get("tradeTypeName"),
                "보증금_또는_매매가": a.get("dealOrWarrantPrc"),
                "월세": a.get("rentPrc", ""),
                "층수": a.get("floorInfo"),
                "평형_공급": a.get("area1"),
                "평형_전용": a.get("area2"),
                "방향": a.get("direction"),
                "확인일": a.get("articleConfirmYmd"),
                "건물명": a.get("buildingName"),
                "설명": a.get("articleFeatureDesc"),
                "태그": ", ".join(a.get("tagList", [])),
                "공인중개사": a.get("realtorName"),
                "중개사ID": a.get("realtorId"),
                "대표이미지": a.get("representativeImgUrl"),
                "PC링크": a.get("cpPcArticleUrl"),
                "매물종류": a.get("realEstateTypeName"),
            })

        print(f"{page} 페이지 수집 완료 (총 {len(range(10))}건)")
        if not data.get("isMoreData"):
            break

        page += 1
        time.sleep(1)  # 서버 부하 방지

    return pd.DataFrame(all_articles)

# 여기에 complexNo를 입력 (예: 올림픽파크포레온은 155817)
df = fetch_all_articles(complex_no="155817")

# 저장 예시
df.to_csv("olympic_park_foreon_articles.csv", index=False, encoding='utf-8-sig')
# Out:
# 1 페이지 수집 완료 (총 10건)
# 2 페이지 수집 완료 (총 10건)
# 3 페이지 수집 완료 (총 10건)
# 4 페이지 수집 완료 (총 10건)
# 5 페이지 수집 완료 (총 10건)
# 6 페이지 수집 완료 (총 10건)
# 7 페이지 수집 완료 (총 10건)
# 8 페이지 수집 완료 (총 10건)
# 9 페이지 수집 완료 (총 10건)
# 10 페이지 수집 완료 (총 10건)
# 11 페이지 수집 완료 (총 10건)
# 12 페이지 수집 완료 (총 10건)
# 13 페이지 수집 완료 (총 10건)
# 14 페이지 수집 완료 (총 10건)
# 15 페이지 수집 완료 (총 10건)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-8bdf1a59e2b5> in <cell line: 0>()
#      58
#      59 # 여기에 complexNo를 입력 (예: 올림픽파크포레온은 155817)
# ---> 60 df = fetch_all_articles(complex_no="155817")
#      61
#      62 # 저장 예시
#
# <ipython-input-17-8bdf1a59e2b5> in fetch_all_articles(complex_no)
#      53
#      54         page += 1
# ---> 55         time.sleep(1)  # 서버 부하 방지
#      56
#      57     return pd.DataFrame(all_articles)
#
# KeyboardInterrupt:

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-00cf07b74dcd> in <cell line: 0>()
# ----> 1 df
#
# NameError: name 'df' is not defined
