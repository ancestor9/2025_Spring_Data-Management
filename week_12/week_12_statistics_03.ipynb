# %% [markdown]
# <a href="https://colab.research.google.com/github/ancestor9/2025_Spring_Data-Management/blob/main/week_12/week_12_statistics_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Start

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 명령 결과 모두 보기
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Inferential statistics
# Inferential statistical analysis infers properties of a population. for example by testing hypothesis and deriving estimates

# %%
import numpy as np
np.random.normal()
# Out:
# 0.011323547575254982

# %%
population = np.random.normal(loc= 30, scale = 45, size=10000)  # 평균 30, 분산 45
population.shape
# Out:
# (10000,)

# %%
from IPython.display import Image
Image('../image/boots.png', width=600, height=300)

# %%
bootstrap =[]
estimates=[]

for i in range(1000):
    sample = np.random.choice(a=population, size=100)
    bootstrap.append(sample)
    estimates.append(sample.mean())

len(bootstrap)      # 200번 부트스트래핑
len(bootstrap[0])   # 재표본크기 100개
bootstrap[0][0:10]
# Out:
# array([  30.90860537,   14.04157336,   48.00464831,   52.59213052,
#         102.29461457,  118.05987976,   33.04830602,   49.75301409,
#          52.90176349, -114.06561434])

# %%
import pandas as pd
data = pd.DataFrame(bootstrap).T
data
# Out:
#            0           1          2          3           4           5    \
# 0    30.908605   41.587328  13.713101  29.031238   37.042942   33.035008
# 1    14.041573   22.195922  46.124235  35.885992   16.948263   20.000655
# 2    48.004648   54.841429  17.872647 -77.259344   27.992049   25.731931
# 3    52.592131   80.691950  55.186659  46.537999   24.181739   55.197168
# 4   102.294615   87.204456 -38.239169 -10.401942   69.012145  120.430752
# ..         ...         ...        ...        ...         ...         ...
# 95  101.130541  -45.175753   4.892377 -22.489507   34.411189   37.207372
# 96  -20.786579   17.596830  59.842178  37.351659   34.639310   36.107287
# 97   18.215115   -0.431819  39.544542  32.156500   61.364060   74.761560
# 98   77.650523   20.286743  80.869361  93.892771  120.721047  -13.722356
# 99  111.123429  116.518264  40.274462  64.903007   56.564174  -39.699158
#
#            6           7          8          9    ...        990        991  \
# ...

# %%
data.describe().head(3)
# Out:
#               0           1           2           3           4           5    \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    35.769841   29.172935   33.298221   29.880406   37.599736   25.972501
# std     44.986810   49.918403   46.779052   38.734698   40.089103   46.495003
#
#               6           7           8           9    ...         990  \
# count  100.000000  100.000000  100.000000  100.000000  ...  100.000000
# mean    30.150804   34.244670   32.362846   31.779067  ...   29.941080
# std     46.524088   46.944847   49.078184   43.312610  ...   37.720725
#
#               991         992         993         994         995         996  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    27.465454   25.876861   34.035655   30.786355   27.156571   29.595447
# std     44.354197   44.714359   40.625223   51.301179   36.262254   38.581201
#
#               997         998         999
# ...

# %%
data[0].plot(figsize=(20,5), kind='kde')
data[1].plot(figsize=(20,5), kind='kde')
data[2].plot(figsize=(20,5), kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
oob = [x.round(2) for x in population if x not in data.values]
print(f'The Number of OOB(Out of Bags) Sample: {len(oob)}')
# Out:
# The Number of OOB(Out of Bags) Sample: 0

# %% [markdown]
# # <font color='red'> 2. 시각화와 통계량
# ## 상관계수
# ## Load the example dataset for Anscombe's quartet

# %%
import seaborn as sns
data = sns.load_dataset("anscombe")
data
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
# data.groupby(['dataset'])['x', 'y'].agg(['mean', 'std', 'skew']) # Original line with error
data.groupby(['dataset'])[['x', 'y']].agg(['mean', 'std', 'skew']) # Changed to use a list for column selection
# Out:
#            x                                 y
#         mean       std          skew      mean       std      skew
# dataset
# I        9.0  3.316625  2.380408e-16  7.500909  2.031568 -0.065036
# II       9.0  3.316625  2.380408e-16  7.500909  2.031657 -1.315798
# III      9.0  3.316625  2.380408e-16  7.500000  2.030424  1.855495
# IV       9.0  3.316625  3.316625e+00  7.500909  2.030579  1.506818

# %%
# Show the results of a linear regression within each dataset
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=data,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})

# %% [markdown]
# # End
