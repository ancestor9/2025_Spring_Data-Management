# %% [markdown]
# <a href="https://colab.research.google.com/github/ancestor9/2025_Spring_Data-Management/blob/main/week_10/%EA%B3%B5%EA%B3%B5%EB%8D%B0%EC%9D%B4%ED%84%B0_Preprocessing_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## [공공데이터 다운받기](https://www.data.go.kr/data/15028200/standard.do#tab_layer_grid)
# - API로 받거나 직접 받는다
# ### 동영상[[엑셀] 클릭만 하면 하면 내용이 휙휙 바뀌는 엑셀 대시보드 만들기(초딩도 가능) EP.14](https://www.data.go.kr/data/15028200/standard.do#tab_layer_grid)

# %%
import requests

url = 'http://api.data.go.kr/openapi/tn_pubr_public_unmanned_traffic_camera_api'
params ={'serviceKey' : 'wm2TPT6dZnR3wpi1E+Q0JtDAgPRPv6mODahI5P+OV7QeIxMhXRqQ0D+qjqi8k2TCRqKFmp23DPRoIJdrz2tZXA==', 'pageNo' : '1', 'numOfRows' : '100', 'type' : 'xml', 'mnlssRegltCameraManageNo' : '', 'ctprvnNm' : '', 'signguNm' : '', 'roadKnd' : '', 'roadRouteNo' : '', 'roadRouteNm' : '', 'roadRouteDrc' : '', 'rdnmadr' : '', 'lnmadr' : '', 'latitude' : '', 'longitude' : '', 'itlpc' : '', 'regltSe' : '', 'lmttVe' : '', 'regltSctnLcSe' : '', 'ovrspdRegltSctnLt' : '', 'prtcareaType' : '', 'installationYear' : '', 'institutionNm' : '', 'phoneNumber' : '', 'referenceDate' : '', 'instt_code' : '' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\r\n<response><header><resultCode>30</resultCode><resultMsg>SERVICE KEY IS NOT REGISTERED ERROR.</resultMsg></header></response>\r\n'

# %%
import requests

url = 'http://apis.data.go.kr/1661000/EmergencyInformationService/getEmgPatientTransferInfo'
params ={'serviceKey' : 'wm2TPT6dZnR3wpi1E+Q0JtDAgPRPv6mODahI5P+OV7QeIxMhXRqQ0D+qjqi8k2TCRqKFmp23DPRoIJdrz2tZXA==', 'pageNo' : '1', 'numOfRows' : '2', 'resultType' : 'xml', 'sidoHqOgidNm' : '충청남도소방본부', 'rsacGutFsttOgidNm' : '공주소방서', 'stmtYm' : '202101' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<OpenAPI_ServiceResponse>\n\t<cmmMsgHeader>\n\t\t<errMsg>SERVICE ERROR</errMsg>\n\t\t<returnAuthMsg>HTTP ROUTING ERROR</returnAuthMsg>\n\t\t<returnReasonCode>04</returnReasonCode>\n\t</cmmMsgHeader>\n</OpenAPI_ServiceResponse>'

# %%
# prompt: /content/전국무인교통단속카메라표준데이터-20250418.xls 을 pandas로 읽기

import pandas as pd

# Assuming the file is in the /content directory as specified
file_path = '/content/전국무인교통단속카메라표준데이터-20250418.xls'

try:
  # Attempt to read the Excel file using pandas
  df = pd.read_excel(file_path)
  print(df.head())  # Print the first few rows to verify

except FileNotFoundError:
  print(f"Error: File not found at {file_path}")
except Exception as e:
  print(f"An error occurred: {e}")
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  무인교통단속카메라관리번호        시도명       시군구명       도로종류     도로노선번호      도로노선명
# 1          G3034        경기도        수원시        지방도       9999        수인로
# 2          F7704    전북특별자치도        고창군       일반국도         22       선운대로
# 3          F7705    전북특별자치도        완주군       일반국도          1        호남로
# 4          F7706    전북특별자치도        완주군       일반국도          1        호남로
#
#   Unnamed: 6 Unnamed: 7                   Unnamed: 8   Unnamed: 9  ...  \
# 0     도로노선방향   소재지도로명주소                      소재지지번주소           위도  ...
# 1          3        NaN        경기도 수원시 권선구 구운동 956-1  37.27909311  ...
# 2          2        NaN    전북특별자치도 고창군 심원면 용기리 154-4  35.53849582  ...
# 3          1        NaN      전북특별자치도 완주군 이서면 갈산리 708  35.83921515  ...
# 4          2        NaN  전북특별자치도 완주군 이서면 금평리 198-349  35.83275051  ...
#
#   Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# ...

# %%
df
# Out:
#           Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0      무인교통단속카메라관리번호        시도명       시군구명       도로종류     도로노선번호      도로노선명
# 1              G3034        경기도        수원시        지방도       9999        수인로
# 2              F7704    전북특별자치도        고창군       일반국도         22       선운대로
# 3              F7705    전북특별자치도        완주군       일반국도          1        호남로
# 4              F7706    전북특별자치도        완주군       일반국도          1        호남로
# ...              ...        ...        ...        ...        ...        ...
# 40049          J7597      서울특별시        중랑구       특별시도        NaN       봉화산로
# 40050          J7598      서울특별시        중랑구       특별시도        NaN       봉화산로
# 40051          J7599      서울특별시        중랑구       특별시도        NaN       봉화산로
# 40052          J7611       전라남도        해남군       일반국도         18        해강로
# 40053          J7612       전라남도        강진군       일반국도         18        해강로
#
# ...

# %%
# prompt: df 첫번쨰 행을 컬럼명으로

import pandas as pd
# Assuming the file is in the /content directory as specified
file_path = '/content/전국무인교통단속카메라표준데이터-20250418.xls'

try:
  # Attempt to read the Excel file using pandas
  df = pd.read_excel(file_path, header=1) # header=1 makes the second row the column names

except FileNotFoundError:
  print(f"Error: File not found at {file_path}")
except Exception as e:
  print(f"An error occurred: {e}")

df
# Out:
#       무인교통단속카메라관리번호      시도명 시군구명  도로종류 도로노선번호   도로노선명  도로노선방향  \
# 0             G3034      경기도  수원시   지방도   9999     수인로       3
# 1             F7704  전북특별자치도  고창군  일반국도     22    선운대로       2
# 2             F7705  전북특별자치도  완주군  일반국도      1     호남로       1
# 3             F7706  전북특별자치도  완주군  일반국도      1     호남로       2
# 4             F7714     충청북도  청주시    기타    NaN  25번 국도       2
# ...             ...      ...  ...   ...    ...     ...     ...
# 40048         J7597    서울특별시  중랑구  특별시도    NaN    봉화산로       1
# 40049         J7598    서울특별시  중랑구  특별시도    NaN    봉화산로       2
# 40050         J7599    서울특별시  중랑구  특별시도    NaN    봉화산로       1
# 40051         J7611     전라남도  해남군  일반국도     18     해강로       2
# 40052         J7612     전라남도  강진군  일반국도     18     해강로       1
#
#                  소재지도로명주소                      소재지지번주소         위도  ...  제한속도  \
# 0                     NaN        경기도 수원시 권선구 구운동 956-1  37.279093  ...    60
# ...

# %%
df.columns
# Out:
# Index(['무인교통단속카메라관리번호', '시도명', '시군구명', '도로종류', '도로노선번호', '도로노선명', '도로노선방향',
#        '소재지도로명주소', '소재지지번주소', '위도', '경도', '설치장소', '단속구분', '제한속도', '단속구간위치구분',
#        '과속단속구간길이', '보호구역구분', '설치연도', '관리기관명', '관리기관전화번호', '데이터기준일자', '제공기관코드',
#        '제공기관명'],
#       dtype='object')
